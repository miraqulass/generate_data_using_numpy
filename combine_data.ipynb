# %%
import pandas as pd
import numpy as np

# %%
sensor_data = pd.read_csv('~/PycharmProjects/ML-Project/GenerateData/sensorData/sensor_data.csv')

# %%
sensor_data
# Out:
#       Time  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0        0    88.461143  28.331791            7    87.243017
# 1        1    88.832327  60.297278            5    96.544692
# 2        2    90.548790  51.474838            5    85.793646
# 3        3    86.756911  35.206521            3    86.310444
# 4        4    90.106142  27.012264            8    88.455254
# ...    ...          ...        ...          ...          ...
# 9995  9995    87.718888  45.248076            5    89.863420
# 9996  9996    87.501622  66.111435            8    87.138987
# 9997  9997    91.280958  38.054916            8    87.989679
# 9998  9998    92.576612  37.945161            6    89.140857
# 9999  9999    91.003646  41.064169            7    89.206413
#
#       ThrottlePosition   MAPSensor  OxygenSensor  RainSensor  VoltageSensor  \
# 0            50.813364  103.461988     -0.004333    0.914245      11.497810
# 1             6.476938   81.555006     -0.584690    2.623400      12.714626
# ...

# %%
telematics_data = pd.read_csv('~/PycharmProjects/ML-Project/GenerateData/telematicsData/telematics_data_random_route.csv')

# %%
telematics_data
# Out:
#       Time                      GPS  Speed(km/hr)  Acceleration
# 0        0   (-1.286389, 36.817223)      5.000000      0.000000
# 1        1    (0.326729, 36.367464)      0.000000     -5.000000
# 2        2    (1.994921, 36.567686)      0.000000     -0.268499
# 3        3    (2.760388, 35.934676)      0.000000     -4.082528
# 4        4    (2.156461, 36.766943)      0.000000     -0.587396
# ...    ...                      ...           ...           ...
# 9995  9995  (-51.529496, 30.545795)     99.985973     -0.014027
# 9996  9996    (50.03215, 42.140232)     99.998398      0.012424
# 9997  9997  (-49.678949, 34.547154)    100.000000      1.082772
# 9998  9998   (49.945313, 38.496054)    100.000000      1.290056
# 9999  9999  (-52.565877, 33.617976)     98.291723     -1.708277
#
# [10000 rows x 4 columns]

# %%
maintenance_data = pd.read_csv('~/PycharmProjects/ML-Project/GenerateData/maintenanceRecords/maintenance_data.csv')

# %%
maintenance_data
# Out:
#        VehicleID            Timestamp         MaintenanceType  \
# 0              1  2022-12-23 15:54:26       Brake Replacement
# 1              1  2022-12-23 15:54:26           Tire Rotation
# 2              1  2022-12-23 15:54:26  Air Filter Replacement
# 3              1  2022-12-23 15:54:26              Oil Change
# 4              2  2023-06-18 11:53:31           Tire Rotation
# ...          ...                  ...                     ...
# 39995       9999  2023-05-23 20:22:33           Tire Rotation
# 39996      10000  2022-12-09 23:35:38              Oil Change
# 39997      10000  2022-12-09 23:35:38       Brake Replacement
# 39998      10000  2022-12-09 23:35:38           Tire Rotation
# 39999      10000  2022-12-09 23:35:38  Air Filter Replacement
#
#        MaintenanceCategory MaintenanceFrequency MaintenanceSeverity  \
# 0                  Repairs            As needed                High
# 1      Routine Maintenance       Every 3 months            Moderate
# ...

# %%
sensor_data['VehicleID'] = range(1, len(sensor_data) + 1)

# %%
sensor_data
# Out:
#       Time  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0        0    88.461143  28.331791            7    87.243017
# 1        1    88.832327  60.297278            5    96.544692
# 2        2    90.548790  51.474838            5    85.793646
# 3        3    86.756911  35.206521            3    86.310444
# 4        4    90.106142  27.012264            8    88.455254
# ...    ...          ...        ...          ...          ...
# 9995  9995    87.718888  45.248076            5    89.863420
# 9996  9996    87.501622  66.111435            8    87.138987
# 9997  9997    91.280958  38.054916            8    87.989679
# 9998  9998    92.576612  37.945161            6    89.140857
# 9999  9999    91.003646  41.064169            7    89.206413
#
#       ThrottlePosition   MAPSensor  OxygenSensor  RainSensor  VoltageSensor  \
# 0            50.813364  103.461988     -0.004333    0.914245      11.497810
# 1             6.476938   81.555006     -0.584690    2.623400      12.714626
# ...

# %%
sensor_data = sensor_data[['VehicleID'] + [col for col in sensor_data.columns if col != 'VehicleID']]

# %%
sensor_data
# Out:
#       VehicleID  Time  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0             1     0    88.461143  28.331791            7    87.243017
# 1             2     1    88.832327  60.297278            5    96.544692
# 2             3     2    90.548790  51.474838            5    85.793646
# 3             4     3    86.756911  35.206521            3    86.310444
# 4             5     4    90.106142  27.012264            8    88.455254
# ...         ...   ...          ...        ...          ...          ...
# 9995       9996  9995    87.718888  45.248076            5    89.863420
# 9996       9997  9996    87.501622  66.111435            8    87.138987
# 9997       9998  9997    91.280958  38.054916            8    87.989679
# 9998       9999  9998    92.576612  37.945161            6    89.140857
# 9999      10000  9999    91.003646  41.064169            7    89.206413
#
#       ThrottlePosition   MAPSensor  OxygenSensor  RainSensor  VoltageSensor  \
# ...

# %%
telematics_data['VehicleID'] = range(1, len(telematics_data) + 1)

# %%
telematics_data
# Out:
#       Time                      GPS  Speed(km/hr)  Acceleration  VehicleID
# 0        0   (-1.286389, 36.817223)      5.000000      0.000000          1
# 1        1    (0.326729, 36.367464)      0.000000     -5.000000          2
# 2        2    (1.994921, 36.567686)      0.000000     -0.268499          3
# 3        3    (2.760388, 35.934676)      0.000000     -4.082528          4
# 4        4    (2.156461, 36.766943)      0.000000     -0.587396          5
# ...    ...                      ...           ...           ...        ...
# 9995  9995  (-51.529496, 30.545795)     99.985973     -0.014027       9996
# 9996  9996    (50.03215, 42.140232)     99.998398      0.012424       9997
# 9997  9997  (-49.678949, 34.547154)    100.000000      1.082772       9998
# 9998  9998   (49.945313, 38.496054)    100.000000      1.290056       9999
# 9999  9999  (-52.565877, 33.617976)     98.291723     -1.708277      10000
#
# [10000 rows x 5 columns]

# %%
telematics_data = telematics_data[['VehicleID'] + [col for col in telematics_data.columns if col != 'VehicleID']]

# %%
telematics_data
# Out:
#       VehicleID  Time                      GPS  Speed(km/hr)  Acceleration
# 0             1     0   (-1.286389, 36.817223)      5.000000      0.000000
# 1             2     1    (0.326729, 36.367464)      0.000000     -5.000000
# 2             3     2    (1.994921, 36.567686)      0.000000     -0.268499
# 3             4     3    (2.760388, 35.934676)      0.000000     -4.082528
# 4             5     4    (2.156461, 36.766943)      0.000000     -0.587396
# ...         ...   ...                      ...           ...           ...
# 9995       9996  9995  (-51.529496, 30.545795)     99.985973     -0.014027
# 9996       9997  9996    (50.03215, 42.140232)     99.998398      0.012424
# 9997       9998  9997  (-49.678949, 34.547154)    100.000000      1.082772
# 9998       9999  9998   (49.945313, 38.496054)    100.000000      1.290056
# 9999      10000  9999  (-52.565877, 33.617976)     98.291723     -1.708277
#
# [10000 rows x 5 columns]

# %%
combinedd_data = pd.merge(sensor_data, telematics_data, on='VehicleID', how='inner')

# %%
combinedd_data
# Out:
#       VehicleID  Time_x  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0             1       0    88.461143  28.331791            7    87.243017
# 1             2       1    88.832327  60.297278            5    96.544692
# 2             3       2    90.548790  51.474838            5    85.793646
# 3             4       3    86.756911  35.206521            3    86.310444
# 4             5       4    90.106142  27.012264            8    88.455254
# ...         ...     ...          ...        ...          ...          ...
# 9995       9996    9995    87.718888  45.248076            5    89.863420
# 9996       9997    9996    87.501622  66.111435            8    87.138987
# 9997       9998    9997    91.280958  38.054916            8    87.989679
# 9998       9999    9998    92.576612  37.945161            6    89.140857
# 9999      10000    9999    91.003646  41.064169            7    89.206413
#
#       ThrottlePosition   MAPSensor  OxygenSensor  RainSensor  VoltageSensor  \
# ...

# %%
combinedd_data = pd.merge(combinedd_data, maintenance_data, on='VehicleID', how='inner')

# %%
combinedd_data
# Out:
#        VehicleID  Time_x  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0              1       0    88.461143  28.331791            7    87.243017
# 1              1       0    88.461143  28.331791            7    87.243017
# 2              1       0    88.461143  28.331791            7    87.243017
# 3              1       0    88.461143  28.331791            7    87.243017
# 4              2       1    88.832327  60.297278            5    96.544692
# ...          ...     ...          ...        ...          ...          ...
# 39995       9999    9998    92.576612  37.945161            6    89.140857
# 39996      10000    9999    91.003646  41.064169            7    89.206413
# 39997      10000    9999    91.003646  41.064169            7    89.206413
# 39998      10000    9999    91.003646  41.064169            7    89.206413
# 39999      10000    9999    91.003646  41.064169            7    89.206413
#
# ...

# %%
combinedd_data.describe()
# Out:
#           VehicleID        Time_x   Temperature         Speed   EngineKnock  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean    5000.500000   4999.500000     89.968837     44.982574      4.979300
# std     2886.787417   2886.787417      2.128487     14.359802      2.209523
# min        1.000000      0.000000     81.801873     20.015546      0.000000
# 25%     2500.750000   2499.750000     88.538191     32.581536      3.000000
# 50%     5000.500000   4999.500000     89.957561     45.022634      5.000000
# 75%     7500.250000   7499.250000     91.398353     57.364276      6.000000
# max    10000.000000   9999.000000     97.958232     69.999056     15.000000
#
#         CoolantTemp  ThrottlePosition     MAPSensor  OxygenSensor  \
# count  40000.000000      40000.000000  40000.000000  40000.000000
# mean      90.039889         50.448153     99.913455      0.202375
# std        2.128112         29.094622     11.618891      1.998953
# ...

# %%
combinedd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40000 entries, 0 to 39999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   VehicleID             40000 non-null  int64
#  1   Time_x                40000 non-null  int64
#  2   Temperature           40000 non-null  float64
#  3   Speed                 40000 non-null  float64
#  4   EngineKnock           40000 non-null  int64
#  5   CoolantTemp           40000 non-null  float64
#  6   ThrottlePosition      40000 non-null  float64
#  7   MAPSensor             40000 non-null  float64
#  8   OxygenSensor          40000 non-null  float64
#  9   RainSensor            40000 non-null  float64
#  10  VoltageSensor         40000 non-null  float64
#  11  CamshaftPosition      40000 non-null  float64
#  12  Time_y                40000 non-null  int64
#  13  GPS                   40000 non-null  object
# ...

# %%
combinedd_data
# Out:
#        VehicleID  Time_x  Temperature      Speed  EngineKnock  CoolantTemp  \
# 0              1       0    88.461143  28.331791            7    87.243017
# 1              1       0    88.461143  28.331791            7    87.243017
# 2              1       0    88.461143  28.331791            7    87.243017
# 3              1       0    88.461143  28.331791            7    87.243017
# 4              2       1    88.832327  60.297278            5    96.544692
# ...          ...     ...          ...        ...          ...          ...
# 39995       9999    9998    92.576612  37.945161            6    89.140857
# 39996      10000    9999    91.003646  41.064169            7    89.206413
# 39997      10000    9999    91.003646  41.064169            7    89.206413
# 39998      10000    9999    91.003646  41.064169            7    89.206413
# 39999      10000    9999    91.003646  41.064169            7    89.206413
#
# ...

# %%
combinedd_data = combinedd_data.drop(['Time_x', 'Time_y'], axis=1)

# %%
combinedd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40000 entries, 0 to 39999
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   VehicleID             40000 non-null  int64
#  1   Temperature           40000 non-null  float64
#  2   Speed                 40000 non-null  float64
#  3   EngineKnock           40000 non-null  int64
#  4   CoolantTemp           40000 non-null  float64
#  5   ThrottlePosition      40000 non-null  float64
#  6   MAPSensor             40000 non-null  float64
#  7   OxygenSensor          40000 non-null  float64
#  8   RainSensor            40000 non-null  float64
#  9   VoltageSensor         40000 non-null  float64
#  10  CamshaftPosition      40000 non-null  float64
#  11  GPS                   40000 non-null  object
#  12  Speed(km/hr)          40000 non-null  float64
#  13  Acceleration          40000 non-null  float64
# ...

# %%
col = combinedd_data.pop('Timestamp')
combinedd_data.insert(1, col.name, col)

# %%
combinedd_data
# Out:
#        VehicleID            Timestamp  Temperature      Speed  EngineKnock  \
# 0              1  2022-12-23 15:54:26    88.461143  28.331791            7
# 1              1  2022-12-23 15:54:26    88.461143  28.331791            7
# 2              1  2022-12-23 15:54:26    88.461143  28.331791            7
# 3              1  2022-12-23 15:54:26    88.461143  28.331791            7
# 4              2  2023-06-18 11:53:31    88.832327  60.297278            5
# ...          ...                  ...          ...        ...          ...
# 39995       9999  2023-05-23 20:22:33    92.576612  37.945161            6
# 39996      10000  2022-12-09 23:35:38    91.003646  41.064169            7
# 39997      10000  2022-12-09 23:35:38    91.003646  41.064169            7
# 39998      10000  2022-12-09 23:35:38    91.003646  41.064169            7
# 39999      10000  2022-12-09 23:35:38    91.003646  41.064169            7
#
# ...

# %%
combinedd_data.to_csv('combined_data.csv', index=False)
